# %% [markdown]
# <a href="https://colab.research.google.com/github/ashigupta99/Finlatics_Python_ML/blob/main/Sales_advertisem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('advertising.csv')

# %% [markdown]
# #**Ques1**

# %% [markdown]
# Average amt spent on tv

# %%
avg = dataset['TV'].mean()
print(avg)
# Out:
# 147.0425

# %% [markdown]
# # **Ques2**

# %%
dataset['radio']=dataset.iloc[:,2].values
dataset['sales']=dataset.iloc[:,4].values
corr= dataset[['radio','sales']].corr()
print(corr)
# Out:
#           radio     sales
# radio  1.000000  0.349728
# sales  0.349728  1.000000

# %% [markdown]
# Correlation is weak positive(0.35)

# %% [markdown]
# # **Ques3**

# %%
print(regressor.coef_)
# Out:
# [ 0.05507913  0.10310711 -0.00091872]

# %% [markdown]
# As the coefficient for variable 1 that is TV is the highest positive integer, so impact of TV on sales is the most.

# %% [markdown]
# # **Ques4**

# %%
x=dataset.iloc[:,[1,2,3]].values
y=dataset.iloc[:,-1].values

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(x[:,0:3])
x[:,0:3]=imputer.transform(x[:,0:3])
print(x)
# Out:
# [[230.1         37.8         69.2       ]
#  [ 44.5         39.3         45.1       ]
#  [ 17.2         45.9         69.3       ]
#  [151.5         41.3         58.5       ]
#  [180.8         10.8         58.4       ]
#  [  8.7         48.9         75.        ]
#  [ 57.5         32.8         23.5       ]
#  [120.2         19.6         11.6       ]
#  [  8.6          2.1          1.        ]
#  [199.8          2.6         21.2       ]
#  [ 66.1          5.8         24.2       ]
#  [214.7         24.           4.        ]
#  [ 23.8         35.1         65.9       ]
#  [ 97.5          7.6          7.2       ]
#  [204.1         32.9         46.        ]
#  [195.4         47.7         52.9       ]
#  [ 67.8         36.6        114.        ]
#  [281.4         39.6         55.8       ]
#  [ 69.2         20.5         18.3       ]
#  [147.3         23.26060606  19.1       ]
#  [218.4         27.7         53.4       ]
#  [237.4          5.1         23.5       ]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[ 13.1          0.4         25.6       ]
#  [ 90.4          0.3         23.2       ]
#  [ 18.7         12.1         23.4       ]
#  [204.1         32.9         46.        ]
#  [  7.3         28.1         41.4       ]
#  [147.3         23.26060606  19.1       ]
#  [ 78.2         46.8         34.5       ]
#  [228.          37.7         32.        ]
#  [205.          45.1         19.6       ]
#  [229.5         32.3         74.2       ]
#  [289.7         42.3         51.2       ]
#  [123.1         34.6         12.4       ]
#  [ 19.4         16.          22.3       ]
#  [182.6         46.2         58.7       ]
#  [265.6         20.           0.3       ]
#  [165.6         10.          17.6       ]
#  [218.5          5.4         27.4       ]
#  [ 25.          11.          29.7       ]
#  [232.1          8.6          8.7       ]
#  [ 43.          25.9         20.5       ]
#  [139.2         14.3         25.6       ]
#  [139.3         14.5         10.2       ]
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
plt.title('Actual vs Predicted Sales')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.show()

# %% [markdown]
# # **Ques5**

# %%
inp=np.array([[200,40,50]])
print(regressor.predict(inp))
# Out:
# [19.7321937]

# %% [markdown]
# The prediction for a new set

# %% [markdown]
# # **Ques6**

# %% [markdown]
# Scaled or Normalised model

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor_sc=LinearRegression()
regressor_sc.fit(x_train_sc,y_train)
# Out:
# LinearRegression()

# %%
y_predc=regressor_sc.predict(x_test_sc)

# %%
plt.scatter(y_test, y_predc, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
plt.title('Actual vs Predicted Sales')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_predc))
print(r2_score(y_test, y_predc))
# Out:
# 2.4092185773771497
# 0.8747286106321062
# 2.4092185773771484
# 0.8747286106321063

# %% [markdown]
# A little difference in the MSE and r2 score, error decreases in scaled and r2 score increases in scaled model.
# So model is performing better

# %% [markdown]
# # **Ques7**

# %%
x1=dataset.iloc[:,[2,3]].values
y1=dataset.iloc[:,-1].values

# %%
from sklearn.impute import SimpleImputer
imputer1=SimpleImputer(missing_values=np.nan, strategy='mean')
imputer1.fit(x1[:,0:2])
x1[:,0:2]=imputer1.transform(x1[:,0:2])
print(x1)
# Out:
# [[ 37.8         69.2       ]
#  [ 39.3         45.1       ]
#  [ 45.9         69.3       ]
#  [ 41.3         58.5       ]
#  [ 10.8         58.4       ]
#  [ 48.9         75.        ]
#  [ 32.8         23.5       ]
#  [ 19.6         11.6       ]
#  [  2.1          1.        ]
#  [  2.6         21.2       ]
#  [  5.8         24.2       ]
#  [ 24.           4.        ]
#  [ 35.1         65.9       ]
#  [  7.6          7.2       ]
#  [ 32.9         46.        ]
#  [ 47.7         52.9       ]
#  [ 36.6        114.        ]
#  [ 39.6         55.8       ]
#  [ 20.5         18.3       ]
#  [ 23.26060606  19.1       ]
#  [ 27.7         53.4       ]
#  [  5.1         23.5       ]
#  [ 15.9         49.6       ]
#  [ 16.9         26.2       ]
#  [ 12.6         18.3       ]
#  [  3.5         19.5       ]
#  [ 29.3         12.6       ]
#  [ 16.7         22.9       ]
#  [ 27.1         22.9       ]
#  [ 16.          40.8       ]
#  [ 28.3         43.2       ]
#  [ 17.4         38.6       ]
# ...

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=1)

# %%
print(x1_train)
print(x1_test)
print(y1_train)
print(y1_test)
# Out:
# [[  0.4         25.6       ]
#  [  0.3         23.2       ]
#  [ 12.1         23.4       ]
#  [ 32.9         46.        ]
#  [ 28.1         41.4       ]
#  [ 23.26060606  19.1       ]
#  [ 46.8         34.5       ]
#  [ 37.7         32.        ]
#  [ 45.1         19.6       ]
#  [ 32.3         74.2       ]
#  [ 42.3         51.2       ]
#  [ 34.6         12.4       ]
#  [ 16.          22.3       ]
#  [ 46.2         58.7       ]
#  [ 20.           0.3       ]
#  [ 10.          17.6       ]
#  [  5.4         27.4       ]
#  [ 11.          29.7       ]
#  [  8.6          8.7       ]
#  [ 25.9         20.5       ]
#  [ 14.3         25.6       ]
#  [ 14.5         10.2       ]
#  [ 29.9          9.4       ]
#  [ 27.7          1.8       ]
#  [ 39.6         55.8       ]
#  [ 48.9         75.        ]
#  [  0.           9.2       ]
#  [ 46.4         59.        ]
#  [ 15.8         49.9       ]
#  [ 24.6          2.2       ]
#  [ 28.8         15.9       ]
#  [ 43.          33.8       ]
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor1=LinearRegression()
regressor1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred=regressor1.predict(x1_test)

# %%
plt.scatter(y1_test, y1_pred, color='blue')
plt.plot([min(y1_test), max(y1_test)], [min(y1_test), max(y1_test)], color='red')
plt.title('Actual vs Predicted Sales')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.show()

# %%
print(mean_squared_error(y_test, y_pred))
print(mean_squared_error(y1_test, y1_pred))
print(r2_score(y_test, y_pred))
print(r2_score(y1_test, y1_pred))
# Out:
# 2.4092185773771497
# 19.082567784662967
# 0.8747286106321062
# 0.007769655464713865

# %% [markdown]
# When sales predicted using Radio and Newspapers, Error increased way too much as is indicated by the graph and r2 score decreased too much
